# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanniamtz/Valores-At-picos/blob/main/Actividad_3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Actividad 3.1**
# ###Hannia Nicole Martínez - A01552310

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("ValoresNulos.csv")
df
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0      01/01/17                    27858.9
# 1            1      01/02/17                    25994.2
# 2            2      01/03/17                    27780.0
# 3            3      01/04/17                    29134.3
# 4            4      01/05/17                    27969.0
# ..         ...           ...                        ...
# 60          60      01/01/22                   154517.1
# 61          61      01/02/22                   152202.6
# 62          62      01/03/22                       16.5
# 63          63      01/04/22                   177148.1
# 64          64      01/05/22                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Identificar valores nulos por columna
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                             0
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0           0      01/01/17                    27858.9
# 1           1      01/02/17                    25994.2
# 2           2      01/03/17                    27780.0
# 3           3      01/04/17                    29134.3
# 4           4      01/05/17                    27969.0
#
#    ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                    27477.3                 27858872.08   27591730.13
# 1                    25223.4                 25994200.17   25749179.40
# 2                    26334.3                 27780006.52   27472228.72
# 3                    27045.9                 29134272.22   28827479.49
# 4                    25631.9                 27969004.68   27569311.41
#
#    canales_on_line  ventas_totales_medio_pago      efectivo  tarjetas_debito  \
# 0       267141.956                27858872.08  1.023010e+07      6864575.384
# ...

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["ventas_precios_corrientes"], color='blue', rwidth=0.50)
plt.title('Histograma de ventas precios corrientes')
plt.xlabel('ventas_precios_corrientes')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["ventas_precios_corrientes"]) 
plt.title("Outliers de ventas precios corrientes")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["ventas_precios_corrientes"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 192319.35000000003
# Limite inferior permitido -59178.650000000016

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 42          42      01/07/20                   211140.7
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 42                    50791.4                 81140696.22   76413721.76
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 42      4726974.457                81140696.22  24935747.29      22143208.63
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 42  ...  23393038.41  2630487.791  9592798.115  8463266.123
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                     518942.5376
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 42                    11217153.19                          2502616.619
#
#     electronicos_articulos_hogar        otros
# 42                   6125265.839  5935993.913
#
# [1 rows x 25 columns]

# %%
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0      01/01/17                    27858.9
# 1            1      01/02/17                    25994.2
# 2            2      01/03/17                    27780.0
# 3            3      01/04/17                    29134.3
# 4            4      01/05/17                    27969.0
# ..         ...           ...                        ...
# 60          60      01/01/22                   154517.1
# 61          61      01/02/22                   152202.6
# 62          62      01/03/22                       16.5
# 63          63      01/04/22                   177148.1
# 64          64      01/05/22                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["ventas_precios_corrientes"]) 
plt.title("Outliers de ventas de precios corrientes")
plt.show() #dibujamos el diagrama

# %%
df.to_csv("OVentasdePreciosCorrientes.csv")
from google.colab import files   
files.download("OVentasdePreciosCorrientes.csv")

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["ventas_precios_constantes"], color='blue', rwidth=0.50)
plt.title('Histograma de ventas precios constantes')
plt.xlabel('ventas_precios_constantes')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["ventas_precios_constantes"]) 
plt.title("Outliers de precios constantes")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["ventas_precios_constantes"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 31938.75
# Limite inferior permitido 18759.949999999997

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 11          11      01/12/17                    40766.3
# 42          42      01/07/20                   211140.7
# 60          60      01/01/22                   154517.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 11                    34084.5                4.076632e+07  4.032029e+07
# 42                    50791.4                8.114070e+07  7.641372e+07
# 60                    45463.4                1.545171e+08  1.496976e+08
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 11     4.460368e+05               4.076632e+07  13710305.37      11070098.74
# 42     4.726974e+06               8.114070e+07  24935747.29      22143208.63
# 60     4.819480e+06               1.545171e+08  46962602.22      46053650.13
#
#     ...       almacen    panaderia       lacteos        carnes  \
# 11  ...  9.667850e+06  1346130.813  3.684165e+06  3.674954e+06
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0      01/01/17                    27858.9
# 1            1      01/02/17                    25994.2
# 2            2      01/03/17                    27780.0
# 3            3      01/04/17                    29134.3
# 4            4      01/05/17                    27969.0
# ..         ...           ...                        ...
# 59          59      01/12/21                   183983.2
# 61          61      01/02/22                   152202.6
# 62          62      01/03/22                       16.5
# 63          63      01/04/22                   177148.1
# 64          64      01/05/22                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote en esta parte se volvio a 
#realizar eesta grafica y como el rango se va actualizando conforme vamos realizando los cambios 
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["ventas_precios_constantes"]) 
plt.title("Outliers de Precio constantes")
plt.show() #dibujamos el diagrama

# %%
df.to_csv("OVentasdePreciosC.csv")
from google.colab import files   
files.download("OVentasdePreciosC.csv")

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["salon_ventas"], color='blue', rwidth=0.50)
plt.title('Histograma de salon de ventas')
plt.xlabel('salon_ventas')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["salon_ventas"]) 
plt.title("Outliers de salon de ventas")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=df["salon_ventas"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 198785582.5945376
# Limite inferior permitido -54394552.868383735

# %%
#Encontramos Ouliers aqui podemos observar que en la caja si me aparece 
#pero al momento de realizar la verificación con todos los codigos no me aparece nada
outliers= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 25 columns]

# %%
df.to_csv("Colum4.csv")
from google.colab import files   
files.download("Colum4.csv")

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["canales_on_line"], color='blue', rwidth=0.50)
plt.title('Histograma de salon de ventas')
plt.xlabel('canales_on_line')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["canales_on_line"]) 
plt.title("Outliers de canales on line")
plt.show() #dibujamos el diagrama

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["ventas_totales_medio_pago"], color='blue', rwidth=0.50)
plt.title('Histograma de ventas totales de medio de pago')
plt.xlabel('ventas_totales_medio_pago')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["ventas_totales_medio_pago"]) 
plt.title("Outliers de ventas totales de medio de pago ")
plt.show() #dibujamos el diagrama

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["efectivo"], color='blue', rwidth=0.50)
plt.title('Histograma de efectivo')
plt.xlabel('efectivo')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["efectivo"]) 
plt.title("Outliers de efectivo ")
plt.show() #dibujamos el diagrama

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["tarjetas_debito"], color='blue', rwidth=0.50)
plt.title('Histograma de tarjeta de debito')
plt.xlabel('tarjetas_debito')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["tarjetas_debito"]) 
plt.title("Outliers de taejtas de debito ")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["tarjetas_debito"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 51933510.0585
# Limite inferior permitido -15937937.1375

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59      01/12/21                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0      01/01/17                    27858.9
# 1            1      01/02/17                    25994.2
# 2            2      01/03/17                    27780.0
# 3            3      01/04/17                    29134.3
# 4            4      01/05/17                    27969.0
# ..         ...           ...                        ...
# 60          60      01/01/22                   154517.1
# 61          61      01/02/22                   152202.6
# 62          62      01/03/22                       16.5
# 63          63      01/04/22                   177148.1
# 64          64      01/05/22                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
df.to_csv("Colum8.csv")
from google.colab import files   
files.download("Colum8.csv")

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["tarjetas_credito"], color='blue', rwidth=0.50)
plt.title('Histograma de tarjeta de credito')
plt.xlabel('tarjetas_credito')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["tarjetas_credito"]) 
plt.title("Outliers de taejtas de credito ")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["tarjetas_credito"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 66191782.864999995
# Limite inferior permitido -18528673.494999994

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 64          64      01/05/22                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 64           6314109.47                     1779482.857
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 64                    23578638.71                          5213152.564
#
#     electronicos_articulos_hogar        otros
# 64                   12039595.55  12349980.06
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0      01/01/17                    27858.9
# 1            1      01/02/17                    25994.2
# 2            2      01/03/17                    27780.0
# 3            3      01/04/17                    29134.3
# 4            4      01/05/17                    27969.0
# ..         ...           ...                        ...
# 59          59      01/12/21                   183983.2
# 60          60      01/01/22                   154517.1
# 61          61      01/02/22                   152202.6
# 62          62      01/03/22                       16.5
# 63          63      01/04/22                   177148.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
df.to_csv("Colum9.csv")
from google.colab import files   
files.download("Colum9.csv")

# %%
#No necesita un archivo ya que no se encontraron ouliers
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["otros_medios"], color='blue', rwidth=0.50)
plt.title('Histograma de otros medios')
plt.xlabel('otros_medios')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["otros_medios"]) 
plt.title("Outliers de otros medios ")
plt.show() #dibujamos el diagrama

#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["otros_medios"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 10650466.405000001
# Limite inferior permitido -3781032.139000001

# %%
#No necesita un archivo ya que no se encontraron ouliers
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["ventas_totales_grupo_articulos"], color='blue', rwidth=0.50)
plt.title('Histograma de ventas totales del grupo de articulo')
plt.xlabel('ventas_totales_grupo_articulos')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["ventas_totales_grupo_articulos"]) 
plt.title("Outliers de ventas totales del grupo de articulo ")
plt.show() #dibujamos el diagrama

#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["ventas_totales_grupo_articulos"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 187511643.5
# Limite inferior permitido -51165850.5

# %%
#No necesita un archivo ya que no se encontraron ouliers
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["subtotal_ventas_alimentos_bebidas"], color='blue', rwidth=0.50)
plt.title('Histograma de subtotal de ventas en alimentos y bebidas')
plt.xlabel('subtotal_ventas_alimentos_bebidas')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["subtotal_ventas_alimentos_bebidas"]) 
plt.title("Outliers de subtotal de ventas en alimentos y bebidas ")
plt.show() #dibujamos el diagrama

#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["subtotal_ventas_alimentos_bebidas"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 130416890.36999999
# Limite inferior permitido -38238188.02999999

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["bebidas"], color='blue', rwidth=0.50)
plt.title('Histograma de bebidas')
plt.xlabel('bebidas')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["bebidas"]) 
plt.title("Outliers de bebidas ")
plt.show() #dibujamos el diagrama

#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["bebidas"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 23788205.776499998
# Limite inferior permitido -7302449.5474999985

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59      01/12/21                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0      01/01/17                    27858.9
# 1            1      01/02/17                    25994.2
# 2            2      01/03/17                    27780.0
# 3            3      01/04/17                    29134.3
# 4            4      01/05/17                    27969.0
# ..         ...           ...                        ...
# 60          60      01/01/22                   154517.1
# 61          61      01/02/22                   152202.6
# 62          62      01/03/22                       16.5
# 63          63      01/04/22                   177148.1
# 64          64      01/05/22                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
df.to_csv("Colum13.csv")
from google.colab import files   
files.download("Colum13.csv")

# %%
#No necesita un archivo ya que no se encontraron ouliers
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["almacen"], color='blue', rwidth=0.50)
plt.title('Histograma de almacen')
plt.xlabel('almacen')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["almacen"]) 
plt.title("Outliers de almacen ")
plt.show() #dibujamos el diagrama

#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["almacen"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 50755333.115499996
# Limite inferior permitido -14779676.552499996

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["panaderia"], color='blue', rwidth=0.50)
plt.title('Histograma de panaderia')
plt.xlabel('panaderia')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["panaderia"]) 
plt.title("Outliers de panaderia ")
plt.show() #dibujamos el diagrama

#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["panaderia"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 5344003.4675
# Limite inferior permitido -946571.9125000001

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 55          55      01/08/21                   124840.3
# 59          59      01/12/21                   183983.2
# 62          62      01/03/22                       16.5
# 63          63      01/04/22                   177148.1
# 64          64      01/05/22                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 55                    23990.1                 124840320.0   120181530.9
# 59                    31595.7                 183983151.9   178866721.2
# 62                    24612.4                 168982502.3   164321107.3
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 55     4.658789e+06                124840320.0  38180625.56      35434522.98
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0      01/01/17                    27858.9
# 1            1      01/02/17                    25994.2
# 2            2      01/03/17                    27780.0
# 3            3      01/04/17                    29134.3
# 4            4      01/05/17                    27969.0
# 5            5      01/06/17                    29132.7
# 6            6      01/07/17                    31182.3
# 7            7      01/08/17                    31154.9
# 8            8      01/09/17                    30521.5
# 9            9      01/10/17                    32446.0
# 10          10      01/11/17                    33629.0
# 11          11      01/12/17                    40766.3
# 12          12      01/01/18                    32479.2
# 13          13      01/02/18                    31736.8
# 14          14      01/03/18                    36531.3
# 15          15      01/04/18                    34113.7
# ...

# %%
df.to_csv("Colum15.csv")
from google.colab import files   
files.download("Colum15.csv")

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["lacteos"], color='blue', rwidth=0.50)
plt.title('Histograma de lacteos')
plt.xlabel('lacteos')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["lacteos"]) 
plt.title("Outliers de lacteos ")
plt.show() #dibujamos el diagrama

#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["lacteos"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 20355207.2205
# Limite inferior permitido -5818090.0075

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 48          48      01/01/21                    98007.6
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 48                    24420.0                 98007583.25   94524545.27
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 48      3483037.987                98007583.25  31878415.61      26481717.36
#
#     ...      almacen    panaderia     lacteos  carnes  verduleria_fruteria  \
# 48  ...  24393220.47  2973192.499  22745271.1     0.0          4076717.804
#
#     alimentos_preparados_rotiseria  articulos_limpieza_perfumeria  \
# 48                     788246.1859                    14237729.54
#
#     indumentaria_calzado_textiles_hogar  electronicos_articulos_hogar  otros
# 48                          2206737.464                           0.0    0.0
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0      01/01/17                    27858.9
# 1            1      01/02/17                    25994.2
# 2            2      01/03/17                    27780.0
# 3            3      01/04/17                    29134.3
# 4            4      01/05/17                    27969.0
# ..         ...           ...                        ...
# 60          60      01/01/22                   154517.1
# 61          61      01/02/22                   152202.6
# 62          62      01/03/22                       16.5
# 63          63      01/04/22                   177148.1
# 64          64      01/05/22                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
df.to_csv("Colum16.csv")
from google.colab import files   
files.download("Colum16.csv")

# %%
#No necesita un archivo ya que no se encontraron ouliers
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["carnes"], color='blue', rwidth=0.50)
plt.title('Histograma de carnes')
plt.xlabel('carnes')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["carnes"]) 
plt.title("Outliers de carnes ")
plt.show() #dibujamos el diagrama

#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["carnes"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 23968996.893999998
# Limite inferior permitido -8565256.29

# %%
#No necesita un archivo ya que no se encontraron ouliers
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["verduleria_fruteria"], color='blue', rwidth=0.50)
plt.title('Histograma de verduleria_fruteria')
plt.xlabel('verduleria_fruteria')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["verduleria_fruteria"]) 
plt.title("Outliers de verduleria_fruteria ")
plt.show() #dibujamos el diagrama

#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["verduleria_fruteria"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 7865869.983
# Limite inferior permitido -2645314.985

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["alimentos_preparados_rotiseria"], color='blue', rwidth=0.50)
plt.title('Histograma de alimentos_preparados_rotiseria')
plt.xlabel('alimentos_preparados_rotiseria')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["alimentos_preparados_rotiseria"]) 
plt.title("Outliers de alimentos_preparados_rotiseria ")
plt.show() #dibujamos el diagrama

#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["alimentos_preparados_rotiseria"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 1587857.7785
# Limite inferior permitido -295824.8606999999

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59      01/12/21                   183983.2
# 62          62      01/03/22                       16.5
# 63          63      01/04/22                   177148.1
# 64          64      01/05/22                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 62                    24612.4                 168982502.3   164321107.3
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59     5.116431e+06                183983151.9  56640033.15      55432191.37
# 62     4.661350e+05                168982502.3  51262080.99      47364363.88
# 63     4.144284e+06                177148082.8  53189998.68      50063972.79
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0      01/01/17                    27858.9
# 1            1      01/02/17                    25994.2
# 2            2      01/03/17                    27780.0
# 3            3      01/04/17                    29134.3
# 4            4      01/05/17                    27969.0
# ..         ...           ...                        ...
# 56          56      01/09/21                   123002.3
# 57          57      01/10/21                   140487.5
# 58          58      01/11/21                   141702.0
# 60          60      01/01/22                   154517.1
# 61          61      01/02/22                   152202.6
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
df.to_csv("Colum19.csv")
from google.colab import files   
files.download("Colum19.csv")

# %%
#No necesita un archivo ya que no se encontraron ouliers
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["articulos_limpieza_perfumeria"], color='blue', rwidth=0.50)
plt.title('Histograma de articulos_limpieza_perfumeria')
plt.xlabel('articulos_limpieza_perfumeria')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["articulos_limpieza_perfumeria"]) 
plt.title("Outliers de articulos_limpieza_perfumeria ")
plt.show() #dibujamos el diagrama

#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["articulos_limpieza_perfumeria"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 27735459.188
# Limite inferior permitido -8258486.54

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["indumentaria_calzado_textiles_hogar"], color='blue', rwidth=0.50)
plt.title('Histograma de indumentaria_calzado_textiles_hogar')
plt.xlabel('indumentaria_calzado_textiles_hogar')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["indumentaria_calzado_textiles_hogar"]) 
plt.title("Outliers de indumentaria_calzado_textiles_hogar ")
plt.show() #dibujamos el diagrama

#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["indumentaria_calzado_textiles_hogar"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 4070013.5714000002
# Limite inferior permitido -898722.7150000001

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59      01/12/21                   183983.2
# 63          63      01/04/22                   177148.1
# 64          64      01/05/22                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
# 63      4144283.743                177148082.8  53189998.68      50063972.79
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0      01/01/17                    27858.9
# 1            1      01/02/17                    25994.2
# 2            2      01/03/17                    27780.0
# 3            3      01/04/17                    29134.3
# 4            4      01/05/17                    27969.0
# ..         ...           ...                        ...
# 57          57      01/10/21                   140487.5
# 58          58      01/11/21                   141702.0
# 60          60      01/01/22                   154517.1
# 61          61      01/02/22                   152202.6
# 62          62      01/03/22                       16.5
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
df.to_csv("Colum21.csv")
from google.colab import files   
files.download("Colum21.csv")

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["electronicos_articulos_hogar"], color='blue', rwidth=0.50)
plt.title('Histograma de electronicos_articulos_hogar')
plt.xlabel('electronicos_articulos_hogar')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["electronicos_articulos_hogar"]) 
plt.title("Outliers de electronicos_articulos_hogar ")
plt.show() #dibujamos el diagrama

#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["electronicos_articulos_hogar"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 12049402.125999998
# Limite inferior permitido -3970031.778

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 58          58      01/11/21                   141702.0
# 59          59      01/12/21                   183983.2
# 60          60      01/01/22                   154517.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 58                    25026.6                 141701960.7   135950778.8
# 59                    31595.7                 183983151.9   178866721.2
# 60                    45463.4                 154517094.2   149697614.6
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 58      5751181.809                141701960.7  43762928.15      39925207.45
# 59      5116430.634                183983151.9  56640033.15      55432191.37
# 60      4819479.554                154517094.2  46962602.22      46053650.13
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 58  ...  36354580.02  4509964.850  14720418.14  15761449.15
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0      01/01/17                    27858.9
# 1            1      01/02/17                    25994.2
# 2            2      01/03/17                    27780.0
# 3            3      01/04/17                    29134.3
# 4            4      01/05/17                    27969.0
# ..         ...           ...                        ...
# 57          57      01/10/21                   140487.5
# 61          61      01/02/22                   152202.6
# 62          62      01/03/22                       16.5
# 63          63      01/04/22                   177148.1
# 64          64      01/05/22                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
df.to_csv("Colum22.csv")
from google.colab import files   
files.download("Colum22.csv")

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize =(5, 3))
plt.hist(x=df["otros"], color='blue', rwidth=0.50)
plt.title('Histograma de otros')
plt.xlabel('otros')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

#Realizamos diagrama de caja o bigote en esta columna no encontramos ouliers
fig = plt.figure(figsize =(10, 6))
plt.boxplot(df["otros"]) 
plt.title("Outliers de otros ")
plt.show() #dibujamos el diagrama

#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=df["otros"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 13645555.3675
# Limite inferior permitido -3393986.2364999987

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59      01/12/21                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0      01/01/17                    27858.9
# 1            1      01/02/17                    25994.2
# 2            2      01/03/17                    27780.0
# 3            3      01/04/17                    29134.3
# 4            4      01/05/17                    27969.0
# ..         ...           ...                        ...
# 60          60      01/01/22                   154517.1
# 61          61      01/02/22                   152202.6
# 62          62      01/03/22                       16.5
# 63          63      01/04/22                   177148.1
# 64          64      01/05/22                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
df.to_csv("VentasTotalescorregido.csv")
from google.colab import files   
files.download("VentasTotalescorregido.csv")
